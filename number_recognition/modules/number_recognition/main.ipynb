# %%
from PIL import Image
from matplotlib import pyplot as plt
import pytesseract
import argparse
import cv2
import os

# %%
img_name = "image.jpg"

img_path = os.path.abspath(os.path.join(os.getcwd(), "..", "..", img_name))
print(img_path)
image = cv2.imread(img_path)
gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
# Out:
# /home/vyacheslav-p/Documents/projects/python/number-recognition/number_recognition/image.jpg

# %%
gray = cv2.threshold(gray, 0, 255,
    cv2.THRESH_BINARY | cv2.THRESH_OTSU)[1]
print(gray.shape)
cut_image = gray[500:900, :]
# write the grayscale image to disk as a temporary file so we can
# apply OCR to   it
filename = "{}.png".format(os.getpid())
cv2.imwrite(filename, cut_image)
# Out:
# (1512, 1512)
# True

# %%
image = Image.open(filename)
plt.imshow(image, cmap="gray")
plt.show()

# %%
# load the image as a PIL/Pillow image, apply OCR, and then delete
# the temporary file
text = pytesseract.image_to_string(image, config="-l eng --psm 13")
os.remove(filename)
print("Text - {}".format(text))
# Out:
# Text -
